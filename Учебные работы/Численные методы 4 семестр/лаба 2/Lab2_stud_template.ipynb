# %% [markdown]
# # Лабораторная работа 2. Решение нелинейных уравнений
# ## Задача 1. Метод простой итерации с выбором параметра

# %% [markdown]
# Подключим необходимые библиотеки.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Определите функцию, её производную, заданную точность и концы отрезка.

# %%
eps=

def P(x):
    
def dP(x):

A = 
B =

# %% [markdown]
# Постройте график функции на отрезке [A,B].
#
# *Для отображения сетки на графике воспользуйтесь командой* `plt.grid('True')`.

# %% [markdown]
# Определите отрезок локализации первого корня по графику.
# Постройте график функции и её производной на данном отрезке и убедитесь, что производная сохраняет на нём знак.

# %%
a1 = 
b1 =

# %% [markdown]
# Определите параметры МПИ для первого корня.

# %%
M1 =  
m1 = 
print(M1,m1)
alpha1 =  
q1 = 
print(alpha1,q1)

# %% [markdown]
# Повторите эти два шага для нахождения параметров второго и третьего корня уравнения.

# %% [markdown]
# Реализуйте функцию метода простой итерации с параметром. Учтите в функции подсчет количества итераций.
#
# *Результат возвращайте как кортеж:* `x, k-1`.

# %%
def MPI(f,x0,eps,alpha,q):
   
    return x, k-1

# %% [markdown]
# Вычислите значения всех корней с помощью МПИ с параметром и напечатайте значение найденных корней и количество проделанных итераций.

# %% [markdown]
# ## Задача 2.

# %% [markdown]
# Определите функцию и её производную.

# %%
def f(x):
    
def df(x):

# %% [markdown]
# Графически локализуйте все корни уравнения.

# %% [markdown]
# Реализуйте метод Ньютона и метод, указанный в индивидуальном варианте. Учтите подсчет итераций методами.

# %% [markdown]
# Вычислите каждый из локализованных корней двумя методами и сравните количество итераций, которые для этого потребовались.
